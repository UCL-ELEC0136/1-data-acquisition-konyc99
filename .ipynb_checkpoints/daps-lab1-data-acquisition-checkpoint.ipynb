# %% [markdown]
# # Task 1: Small case scenario of dataset analysis

# %% [markdown]
# ## 1.1 - Create a dataset (The Tate Collection)
# As a first example, we will create our own small dataset. In particular, the dataset will consist of 10 artists which are present in the Tate Collection along with the corresponding year of birth, year of death, biological gender and number of artworks.
#
# |          Name         | Gender |   Year_Birth  |   Year_Death  | N_works |
# |-----------------------|--------|---------------|---------------|---------|
# |     Beuys, Joseph     |  Male  |      1921	 |      1986     |   588   |
# |    Constable, John    |  Male  |      1776	 |      1837	 |   249   |
# |   Daniell, William    |  Male  |      1769	 |      1837	 |   612   |
# |   Forbes, Elizabeth   | Female |      1859	 |      1912	 |   120   |
# |     Flaxman, John     |  Male  |      1755	 |      1826	 |   287   |
# |    Phillips, Thomas   |  Male  |      1770	 |      1845	 |   274   |
# | Paolozzi, Sir Eduardo |  Male  |      1924	 |      2005	 |   385   |
# |     Schendel, Mira    | Female |      1919	 |      1988	 |    3    |
# |    Turner, William    |  Male  |      1775	 |      1851	 |  1861   |
# |      Warhol, Andy     |  Male  |      1928	 |      1987	 |   272   |

# %% [markdown]
# **_[TO DO]_**: Let's create a DataFrame named **TateDataset** with the information showed in the above table.
#
# **Note:** You can create arrays for each column and then build the DataFrame.
# Remember to import the required libraries!

# %%
# @title Imports
import numpy as np
import pandas as pd

# %%
### TODO
tate_dataset = {'Name': ['Beuys, Joseph ','Constable, John','Daniell, William','Forbes, Elizabeth','Flaxman, John','Phillips, Thomas','Paolozzi, Sir Eduardo','Schendel, Mira','Turner, William','Warhol, Andy'],
                'Gender':['Male','Male','Male','Female','Male','Male','Male','Female','Male','Male'],
                'Year of birth':[1921,1776,1769,1859,1755,1770,1924,1919,1775,1928],
                'Year of death':[1986,1837,1837,1912,1826,1845,2005,1988,1851,1987],
                'Number of works':[588,249,612,120,287,274,385,3,1861,272]
               }
df=pd.DataFrame(tate_dataset)
tate_dataset=df

print(tate_dataset)
# Out:
#                     Name  Gender  Year of birth  Year of death  \
# 0         Beuys, Joseph     Male           1921           1986
# 1        Constable, John    Male           1776           1837
# 2       Daniell, William    Male           1769           1837
# 3      Forbes, Elizabeth  Female           1859           1912
# 4          Flaxman, John    Male           1755           1826
# 5       Phillips, Thomas    Male           1770           1845
# 6  Paolozzi, Sir Eduardo    Male           1924           2005
# 7         Schendel, Mira  Female           1919           1988
# 8        Turner, William    Male           1775           1851
# 9           Warhol, Andy    Male           1928           1987
#
#    Number of works
# 0              588
# 1              249
# 2              612
# 3              120
# 4              287
# 5              274
# 6              385
# 7                3
# 8             1861
# 9              272

# %% [markdown]
# ## 1.2 - Data Acquisition (local file)
#
# Data acquisition is a process of loading and reading data from various sources. We will learn how to export and read data from a local file in different format using  **Pandas** package.
#
# A file format is a standardised way in which information is encoded to be stored in a file. Some examples of file formats are: CSV, XLSX, and PKL.
#
# Let's practice with some examples.
#
# ### .CSV - Comma Separated Values
#
# CSV is one of the most popular spreadsheet file format. In this kind of file, data is stored in cells. Each cell is organized in rows and columns. A column in the spreadsheet file can have different types.
#
# Let us look at how to create a CSV file. We can export a DataFrame with the Pandas function `to_csv()`. The file will be saved in the same location of this notebook unless specified otherwise. We can name the file **TateData.csv**.
#
# **Note:** Once you have run the following cell, check the output file .

# %%
tate_dataset.to_csv('tate_dataset.csv', index=False, header=True)

# %% [markdown]
# To pull in the csv file, we will use the Pandas function `read_csv()`. We will import the previous file in a new DataFrame.
#
# **Note:**  Depending on where you save your notebooks, you may need to modify the location below.

# %%
tate_1 = pd.read_csv('tate_dataset.csv')
tate_1
# Out:
#                     Name  Gender  Year of birth  Year of death  \
# 0         Beuys, Joseph     Male           1921           1986
# 1        Constable, John    Male           1776           1837
# 2       Daniell, William    Male           1769           1837
# 3      Forbes, Elizabeth  Female           1859           1912
# 4          Flaxman, John    Male           1755           1826
# 5       Phillips, Thomas    Male           1770           1845
# 6  Paolozzi, Sir Eduardo    Male           1924           2005
# 7         Schendel, Mira  Female           1919           1988
# 8        Turner, William    Male           1775           1851
# 9           Warhol, Andy    Male           1928           1987
#
#    Number of works
# 0              588
# 1              249
# 2              612
# 3              120
# 4              287
# 5              274
# 6              385
# 7                3
# 8             1861
# 9              272

# %% [markdown]
# When we create the .CSV file, the only parameter we have used is **index**.
#
# **[TO DO]** What happens if we set the *index* parameter to True? And if you set also the parameter **header** to False?
# Try by yourself.

# %%
### TODO
tate_dataset.to_csv('tate_dataset.csv', index=False, header=True)
tate_1 = pd.read_csv('tate_dataset.csv')
tate_1
############
#Cvs file we create writes row names when index is ture
#Header change to false treats the first row of strings as columns names and ommits them when false
#This takes the first row of the table as the header with the default way of representation of data
###########
# Out:
#                     Name  Gender  Year of birth  Year of death  \
# 0         Beuys, Joseph     Male           1921           1986
# 1        Constable, John    Male           1776           1837
# 2       Daniell, William    Male           1769           1837
# 3      Forbes, Elizabeth  Female           1859           1912
# 4          Flaxman, John    Male           1755           1826
# 5       Phillips, Thomas    Male           1770           1845
# 6  Paolozzi, Sir Eduardo    Male           1924           2005
# 7         Schendel, Mira  Female           1919           1988
# 8        Turner, William    Male           1775           1851
# 9           Warhol, Andy    Male           1928           1987
#
#    Number of works
# 0              588
# 1              249
# 2              612
# 3              120
# 4              287
# 5              274
# 6              385
# 7                3
# 8             1861
# 9              272

# %% [markdown]
# Delete the csv file now that we are done using it.

# %% [markdown]
# ### pickle — Python object serialization
#
# This data format is Python-specific. This has the advantage that there are no restrictions imposed by external standards; however it means that non-Python programs may not be able to reconstruct pickled Python objects.

# %%
import pickle

tate_dataset.to_pickle('tate_dataset.pkl')

# %%
tate_2 = pd.read_pickle('tate_dataset.pkl')
tate_2
# Out:
#                     Name  Gender  Year of birth  Year of death  \
# 0         Beuys, Joseph     Male           1921           1986
# 1        Constable, John    Male           1776           1837
# 2       Daniell, William    Male           1769           1837
# 3      Forbes, Elizabeth  Female           1859           1912
# 4          Flaxman, John    Male           1755           1826
# 5       Phillips, Thomas    Male           1770           1845
# 6  Paolozzi, Sir Eduardo    Male           1924           2005
# 7         Schendel, Mira  Female           1919           1988
# 8        Turner, William    Male           1775           1851
# 9           Warhol, Andy    Male           1928           1987
#
#    Number of works
# 0              588
# 1              249
# 2              612
# 3              120
# 4              287
# 5              274
# 6              385
# 7                3
# 8             1861
# 9              272

# %% [markdown]
# ## 1.3 - Look at the data
#
# Now we will simply have a look at the data and make sure it is clean.
#
# ### Data type
# Let's check the data type of the imported variables and the original DataFrame.

# %%
# Check data type of the columns for Tate_1
tate_1.dtypes
# Out:
# Name               object
# Gender             object
# Year of birth       int64
# Year of death       int64
# Number of works     int64
# dtype: object

# %%
# Check data type of the columns for TateDataset
tate_dataset.dtypes
# Out:
# Name               object
# Gender             object
# Year of birth       int64
# Year of death       int64
# Number of works     int64
# dtype: object

# %% [markdown]
# We can also display the values of a single column and check their data type as follow:

# %%
tate_dataset['Gender']
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# 4      Male
# 5      Male
# 6      Male
# 7    Female
# 8      Male
# 9      Male
# Name: Gender, dtype: object

# %% [markdown]
# # Task 2: Application Programming Interfaces (APIs)

# %% [markdown]
# ## 2.1 - Downloading climate data from the Internet
#
# We will now explore real world data, namely a dataset of climate information of 5 cities in Denmark between 1980-2018. The original raw-data was originally obtained from [National Climatic Data Center (NCDC)](https://www7.ncdc.noaa.gov/CDO/cdoselect.cmd).
#
# In particular, the selected cities in Denmark are:
# - Aalborg,
# - Aarhus,
# - Esbjerg,
# - Odense.
# - Roskilde
#
# In the following, we will download the dataset using an API instead of loading a local source file.
#
# ### What is an API?
# Application Programming Interface (API) is a communication protocol between the user and the server (i.e., web server) that enables transmittion of data. The user making a request to an API server can download the desidered resources.
#
# ### How to make a request in python?
# There are many different way to request data.
# In the following, we will use the package **urllib** that collects several modules for working with URLs.
#
# In particular, [urlib.request](https://docs.python.org/3/library/urllib.request.html#module-urllib.request) is a module for opening and reading URLs.

# %% [markdown]
# ### - Download climate data
#
#
# The following functions allow to download and store the dataset in a specific folder.
#
# How to use:
#
# - Set the source (i.e., URL) of the desidered dataset in `data_url`.
# - Set the `data_dir` variable with the local directory where to store the data.
# - Call `download_and_extract()` to download the dataset if it is not already located in the given data_dir.
# - Load the data in the interactive Python notebook so ic can be used in your scripts (you can use `load_original_data()`).

# %%
#@title Functions to download data 
########################################################################
#
# This file is a partially modified version of one of the TensorFlow Tutorials available at:
#
# https://github.com/Hvass-Labs/TensorFlow-Tutorials
#
# Published under the MIT License. See the file LICENSE for details.
#
# Copyright 2018 by Magnus Erik Hvass Pedersen
#
########################################################################

import sys
import os
import urllib.request
import tarfile
import zipfile



def _print_download_progress(count, block_size, total_size):
    """
    Function used for printing the download progress.
    Used as a call-back function in maybe_download_and_extract().
    """

    # Percentage completion.
    pct_complete = float(count * block_size) / total_size

    # Limit it because rounding errors may cause it to exceed 100%.
    pct_complete = min(1.0, pct_complete)

    # Status-message. Note the \r which means the line should overwrite itself.
    msg = "\r- Download progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()


def download(base_url, filename, download_dir):
    """
    Download the given file if it does not already exist in the download_dir.
    :param base_url: The internet URL without the filename.
    :param filename: The filename that will be added to the base_url.
    :param download_dir: Local directory for storing the file.
    """

    # Path for local file.
    save_path = os.path.join(download_dir, filename)

    # Check if the file already exists, otherwise we need to download it now.
    if not os.path.exists(save_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        print("Downloading", filename, "...")

        # Download the file from the internet.
        url = base_url + filename
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=save_path,
                                                  reporthook=_print_download_progress)

        print(" Done!")


def download_and_extract(url, download_dir):
    """
    Download and extract the data if it doesn't already exist.
    Assumes the url is a tar-ball file.
    :param url:
        Internet URL for the tar-file to download.
    :param download_dir:
        Directory where the downloaded file is saved.
    """

    # Filename for saving the file downloaded from the internet.
    # Use the filename from the URL and add it to the download_dir.
    filename = url.split('/')[-1]
    file_path = os.path.join(download_dir, filename)

    # Check if the file already exists.
    # If it exists then we assume it has also been extracted,
    # otherwise we need to download and extract it now.
    if not os.path.exists(file_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        # Download the file from the internet.
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=file_path,
                                                  reporthook=_print_download_progress)

        print()
        print("Download finished. Extracting files.")

        if file_path.endswith(".zip"):
            # Unpack the zip-file.
            zipfile.ZipFile(file=file_path, mode="r").extractall(download_dir)
        elif file_path.endswith((".tar.gz", ".tgz")):
            # Unpack the tar-ball.
            tarfile.open(name=file_path, mode="r:gz").extractall(download_dir)

        print("Done.")
    else:
        print("Data has apparently already been downloaded and unpacked.")

# %% [markdown]
# First, we define where we want to download the dataset (you are free to choose another directory) and the URL of the dataset to be downloaded.

# %%
# Location of the dataset on the internet.
data_url = "https://github.com/Hvass-Labs/weather-denmark/raw/master/weather-denmark.tar.gz"

# Local directory where you want to download and save the dataset.
data_dir = "weather-data/"

# %% [markdown]
# Now, we can download the dataset into the chosen local directory

# %%
download_and_extract(url=data_url, download_dir=data_dir)
# Out:
# - Download progress: 100.0%
# Download finished. Extracting files.
# Done.

# %% [markdown]
# **[TO DO]:** Check the local folder? In which format the dataset has been downloaded?
#
# **[TO DO]:** Select a format and load the dataset .

# %%
### TODO
weather_1 = pd.read_pickle('C:/Users/kondz/1-data-acquisition-konyc99/weather-data/weather-denmark.pkl')
weather_1
# Out:
#                               Temp  Pressure  WindSpeed  WindDir
# City     DateTime
# Aalborg  1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
#          1980-03-01 00:20:00   4.0       NaN        9.2    270.0
#          1980-03-01 00:50:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:20:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...                            ...       ...        ...      ...
# Roskilde 2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
#          2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
#          2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
#          2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
#          2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [2918150 rows x 4 columns]

# %%
### TODO

# %% [markdown]
# **More advanced solution for loading dataset**:
#
# In this case, the dataset was downloaded in two different formats.
# We can define the path where the files have been stored as follows:
# - **path_original_data_pickle( )** is the location of the original data in pickle format
# - **path_original_data_csv( )** is the location the original data in .csv

# %%
def path_original_data_pickle():
    return os.path.join(data_dir, "weather-denmark.pkl")

def path_original_data_csv():
    return os.path.join(data_dir, "weather-denmark.csv")

# %% [markdown]
# Now we can load the data in pickle format through the following function:

# %%
def load_original_data():
    return pd.read_pickle(path_original_data_pickle())

# %%
df = load_original_data()
df
# Out:
#                               Temp  Pressure  WindSpeed  WindDir
# City     DateTime
# Aalborg  1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
#          1980-03-01 00:20:00   4.0       NaN        9.2    270.0
#          1980-03-01 00:50:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:20:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...                            ...       ...        ...      ...
# Roskilde 2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
#          2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
#          2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
#          2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
#          2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [2918150 rows x 4 columns]

# %% [markdown]
# ### - Undestanding the data
#
# **_[TO DO]_**: Have a quick overview of the downloaded dataset.
# In particular, focus on:
#
# - Understanding the variables contained in the dataframe
# - Check the DateTime for 2 cities

# %%
### TODO


#df.dtypes


## Below gives a single temp reading ##
#df.Temp['Aalborg','1980-03-01 00:00:00']

## Acessing all rows with the same name up to column named 'Temp' included ##
df.loc[:'Aalborg',:'Temp']

##slices of dataframe not exacly how accessing the second part of the index is done ##

#df_slice1=df.xs('Aalborg', level='City')
#df_slice1

#df_slice2=df.xs('Roskilde', level='City')
#df_slice2


#bigboi=df.index
#size = bigboi.size
#size=size/5
#print(size)
# Out:
#                              Temp
# City    DateTime
# Aalborg 1980-03-01 00:00:00   5.0
#         1980-03-01 00:20:00   4.0
#         1980-03-01 00:50:00   4.0
#         1980-03-01 01:20:00   4.0
#         1980-03-01 01:50:00   4.0
# ...                           ...
#         2018-03-01 22:50:00  -4.0
#         2018-03-01 23:00:00  -4.2
#         2018-03-01 23:04:00  -4.0
#         2018-03-01 23:21:00  -4.0
#         2018-03-01 23:50:00  -4.0
#
# [759897 rows x 1 columns]

# %% [markdown]
# ## 2.2 - Interacting with a server to query a subset of some data bank
#
# We will now learn how to query a data bank to retrieve only the relevant proportion data for a task. We will be using the World Bank Data API to access World's renewable energy consumtpion data.

# %% [markdown]
# You first need to install the World Bank API. In a terminal, run the following command:
#
# ``>> pip install wbdata``

# %%
# %pip install wbdata
# Out:
# Collecting wbdataNote: you may need to restart the kernel to use updated packages.
#   Downloading wbdata-0.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: decorator>=4.0 in c:\users\kondz\anaconda3\lib\site-packages (from wbdata) (4.4.2)
# Collecting appdirs<2.0,>=1.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting tabulate>=0.8.5
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\kondz\anaconda3\lib\site-packages (from wbdata) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kondz\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kondz\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kondz\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kondz\anaconda3\lib\site-packages (from requests>=2.0->wbdata) (2020.6.20)
# Installing collected packages: appdirs, tabulate, wbdata
# Successfully installed appdirs-1.4.4 tabulate-0.8.9 wbdata-0.3.0

# %%
#@title Imports
import wbdata as wb
import datetime
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# ### - Query the World Bank
#
# * **_[TO DO]_**: Use the wbdata to retrieve renewable energy consumption data of all countries in 2015.
#
# Hint: [wbdata documentation](https://wbdata.readthedocs.io/en/stable/)

# %%
### TODO

wb.get_source()            

wb.get_indicator(source=1)
data_date = datetime.datetime(2015, 1, 1), datetime.datetime(2015, 12, 31)
wb.get_data("EG.FEC.RNEW.ZS", country='all', data_date=data_date)
# Out:
# [{'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#   'countryiso3code': 'AFE',
#   'date': '2015',
#   'value': 61.0972640976963,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#   'countryiso3code': 'AFW',
#   'date': '2015',
#   'value': 76.9675266521529,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': '1A', 'value': 'Arab World'},
#   'countryiso3code': 'ARB',
#   'date': '2015',
#   'value': 4.08075950619097,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'S3', 'value': 'Caribbean small states'},
#   'countryiso3code': 'CSS',
#   'date': '2015',
#   'value': 6.90774357186911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'B8', 'value': 'Central Europe and the Baltics'},
#   'countryiso3code': 'CEB',
#   'date': '2015',
#   'value': 17.1201388969774,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'V2', 'value': 'Early-demographic dividend'},
#   'countryiso3code': 'EAR',
#   'date': '2015',
#   'value': 23.9349841609415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'Z4', 'value': 'East Asia & Pacific'},
#   'countryiso3code': 'EAS',
#   'date': '2015',
#   'value': 13.0922740922061,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': '4E',
#    'value': 'East Asia & Pacific (excluding high income)'},
#   'countryiso3code': 'EAP',
#   'date': '2015',
#   'value': 14.8946425968913,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T4',
#    'value': 'East Asia & Pacific (IDA & IBRD countries)'},
#   'countryiso3code': 'TEA',
#   'date': '2015',
#   'value': 14.8690253314601,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XC', 'value': 'Euro area'},
#   'countryiso3code': 'EMU',
#   'date': '2015',
#   'value': 16.2123010681984,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'Z7', 'value': 'Europe & Central Asia'},
#   'countryiso3code': 'ECS',
#   'date': '2015',
#   'value': 13.0304763115429,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': '7E',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'countryiso3code': 'ECA',
#   'date': '2015',
#   'value': 6.30784210569533,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T7',
#    'value': 'Europe & Central Asia (IDA & IBRD countries)'},
#   'countryiso3code': 'TEC',
#   'date': '2015',
#   'value': 6.9890870318491,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'EU', 'value': 'European Union'},
#   'countryiso3code': 'EUU',
#   'date': '2015',
#   'value': 17.6763660361214,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'F1', 'value': 'Fragile and conflict affected situations'},
#   'countryiso3code': 'FCS',
#   'date': '2015',
#   'value': 63.2189288718212,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#   'countryiso3code': 'HPC',
#   'date': '2015',
#   'value': 76.8970964679277,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XD', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11.3569124992857,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XF', 'value': 'IBRD only'},
#   'countryiso3code': 'IBD',
#   'date': '2015',
#   'value': 16.5761336065293,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZT', 'value': 'IDA & IBRD total'},
#   'countryiso3code': 'IBT',
#   'date': '2015',
#   'value': 22.0455755915032,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XH', 'value': 'IDA blend'},
#   'countryiso3code': 'IDB',
#   'date': '2015',
#   'value': 61.6833266855855,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XI', 'value': 'IDA only'},
#   'countryiso3code': 'IDX',
#   'date': '2015',
#   'value': 70.0994091523163,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XG', 'value': 'IDA total'},
#   'countryiso3code': 'IDA',
#   'date': '2015',
#   'value': 66.0259118585686,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'V3', 'value': 'Late-demographic dividend'},
#   'countryiso3code': 'LTE',
#   'date': '2015',
#   'value': 14.0467725409147,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZJ', 'value': 'Latin America & Caribbean'},
#   'countryiso3code': 'LCN',
#   'date': '2015',
#   'value': 27.9448709833065,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XJ',
#    'value': 'Latin America & Caribbean (excluding high income)'},
#   'countryiso3code': 'LAC',
#   'date': '2015',
#   'value': 29.1572221825113,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T2',
#    'value': 'Latin America & the Caribbean (IDA & IBRD countries)'},
#   'countryiso3code': 'TLA',
#   'date': '2015',
#   'value': 28.2110416781824,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XL',
#    'value': 'Least developed countries: UN classification'},
#   'countryiso3code': 'LDC',
#   'date': '2015',
#   'value': 73.3755726480501,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XO', 'value': 'Low & middle income'},
#   'countryiso3code': 'LMY',
#   'date': '2015',
#   'value': 22.1772821318544,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XM', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76.9421400210301,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XN', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 33.9684429534805,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZQ', 'value': 'Middle East & North Africa'},
#   'countryiso3code': 'MEA',
#   'date': '2015',
#   'value': 1.52331888666162,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XQ',
#    'value': 'Middle East & North Africa (excluding high income)'},
#   'countryiso3code': 'MNA',
#   'date': '2015',
#   'value': 2.46634064426655,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T3',
#    'value': 'Middle East & North Africa (IDA & IBRD countries)'},
#   'countryiso3code': 'TMN',
#   'date': '2015',
#   'value': 2.42383388764119,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XP', 'value': 'Middle income'},
#   'countryiso3code': 'MIC',
#   'date': '2015',
#   'value': 20.440418779748,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XU', 'value': 'North America'},
#   'countryiso3code': 'NAC',
#   'date': '2015',
#   'value': 10.5258683942487,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XY', 'value': 'Not classified'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'OE', 'value': 'OECD members'},
#   'countryiso3code': 'OED',
#   'date': '2015',
#   'value': 12.3722914558863,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'S4', 'value': 'Other small states'},
#   'countryiso3code': 'OSS',
#   'date': '2015',
#   'value': 26.976084652674,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'S2', 'value': 'Pacific island small states'},
#   'countryiso3code': 'PSS',
#   'date': '2015',
#   'value': 30.3495391065949,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'V4', 'value': 'Post-demographic dividend'},
#   'countryiso3code': 'PST',
#   'date': '2015',
#   'value': 11.9807226327198,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'V1', 'value': 'Pre-demographic dividend'},
#   'countryiso3code': 'PRE',
#   'date': '2015',
#   'value': 73.7269690476297,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'S1', 'value': 'Small states'},
#   'countryiso3code': 'SST',
#   'date': '2015',
#   'value': 23.7190813238131,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': '8S', 'value': 'South Asia'},
#   'countryiso3code': 'SAS',
#   'date': '2015',
#   'value': 36.8806957544125,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T5', 'value': 'South Asia (IDA & IBRD)'},
#   'countryiso3code': 'TSA',
#   'date': '2015',
#   'value': 36.8806957544125,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZG', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': 'SSF',
#   'date': '2015',
#   'value': 67.6087232281671,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZF',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'countryiso3code': 'SSA',
#   'date': '2015',
#   'value': 67.6246035056335,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'T6',
#    'value': 'Sub-Saharan Africa (IDA & IBRD countries)'},
#   'countryiso3code': 'TSS',
#   'date': '2015',
#   'value': 67.6087232281671,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XT', 'value': 'Upper middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13.7726335474906,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': '1W', 'value': 'World'},
#   'countryiso3code': 'WLD',
#   'date': '2015',
#   'value': 17.6372561917017,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AF', 'value': 'Afghanistan'},
#   'countryiso3code': 'AFG',
#   'date': '2015',
#   'value': 20.2737998962402,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AL', 'value': 'Albania'},
#   'countryiso3code': 'ALB',
#   'date': '2015',
#   'value': 38.6255989074707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DZ', 'value': 'Algeria'},
#   'countryiso3code': 'DZA',
#   'date': '2015',
#   'value': 0.0590000003576279,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AS', 'value': 'American Samoa'},
#   'countryiso3code': 'ASM',
#   'date': '2015',
#   'value': 1.45869994163513,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AD', 'value': 'Andorra'},
#   'countryiso3code': 'AND',
#   'date': '2015',
#   'value': 19.2777004241943,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AO', 'value': 'Angola'},
#   'countryiso3code': 'AGO',
#   'date': '2015',
#   'value': 47.815601348877,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': 'ATG',
#   'date': '2015',
#   'value': 0.482199996709824,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2015',
#   'value': 9.3931999206543,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AM', 'value': 'Armenia'},
#   'countryiso3code': 'ARM',
#   'date': '2015',
#   'value': 10.7468996047974,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AW', 'value': 'Aruba'},
#   'countryiso3code': 'ABW',
#   'date': '2015',
#   'value': 6.72800016403198,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AU', 'value': 'Australia'},
#   'countryiso3code': 'AUS',
#   'date': '2015',
#   'value': 9.31550025939941,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AT', 'value': 'Austria'},
#   'countryiso3code': 'AUT',
#   'date': '2015',
#   'value': 34.8772010803223,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AZ', 'value': 'Azerbaijan'},
#   'countryiso3code': 'AZE',
#   'date': '2015',
#   'value': 2.31220006942749,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BS', 'value': 'Bahamas, The'},
#   'countryiso3code': 'BHS',
#   'date': '2015',
#   'value': 1.54059994220734,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BH', 'value': 'Bahrain'},
#   'countryiso3code': 'BHR',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BD', 'value': 'Bangladesh'},
#   'countryiso3code': 'BGD',
#   'date': '2015',
#   'value': 34.2163009643555,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BB', 'value': 'Barbados'},
#   'countryiso3code': 'BRB',
#   'date': '2015',
#   'value': 3.17829990386963,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BY', 'value': 'Belarus'},
#   'countryiso3code': 'BLR',
#   'date': '2015',
#   'value': 6.82399988174438,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BE', 'value': 'Belgium'},
#   'countryiso3code': 'BEL',
#   'date': '2015',
#   'value': 9.37609958648682,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BZ', 'value': 'Belize'},
#   'countryiso3code': 'BLZ',
#   'date': '2015',
#   'value': 32.7263984680176,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BJ', 'value': 'Benin'},
#   'countryiso3code': 'BEN',
#   'date': '2015',
#   'value': 49.9431991577148,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BM', 'value': 'Bermuda'},
#   'countryiso3code': 'BMU',
#   'date': '2015',
#   'value': 0.486900001764297,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BT', 'value': 'Bhutan'},
#   'countryiso3code': 'BTN',
#   'date': '2015',
#   'value': 86.6809997558594,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BO', 'value': 'Bolivia'},
#   'countryiso3code': 'BOL',
#   'date': '2015',
#   'value': 8.19859981536865,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BA', 'value': 'Bosnia and Herzegovina'},
#   'countryiso3code': 'BIH',
#   'date': '2015',
#   'value': 25.2754001617432,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BW', 'value': 'Botswana'},
#   'countryiso3code': 'BWA',
#   'date': '2015',
#   'value': 28.2280006408691,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BR', 'value': 'Brazil'},
#   'countryiso3code': 'BRA',
#   'date': '2015',
#   'value': 43.7406005859375,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VG', 'value': 'British Virgin Islands'},
#   'countryiso3code': 'VGB',
#   'date': '2015',
#   'value': 1,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BN', 'value': 'Brunei Darussalam'},
#   'countryiso3code': 'BRN',
#   'date': '2015',
#   'value': 0.0148999998345971,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BG', 'value': 'Bulgaria'},
#   'countryiso3code': 'BGR',
#   'date': '2015',
#   'value': 17.8199005126953,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BF', 'value': 'Burkina Faso'},
#   'countryiso3code': 'BFA',
#   'date': '2015',
#   'value': 72.713996887207,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'BI', 'value': 'Burundi'},
#   'countryiso3code': 'BDI',
#   'date': '2015',
#   'value': 91.1681976318359,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CV', 'value': 'Cabo Verde'},
#   'countryiso3code': 'CPV',
#   'date': '2015',
#   'value': 26.3490009307861,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KH', 'value': 'Cambodia'},
#   'countryiso3code': 'KHM',
#   'date': '2015',
#   'value': 64.9219970703125,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CM', 'value': 'Cameroon'},
#   'countryiso3code': 'CMR',
#   'date': '2015',
#   'value': 78.0355987548828,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CA', 'value': 'Canada'},
#   'countryiso3code': 'CAN',
#   'date': '2015',
#   'value': 22.6422004699707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KY', 'value': 'Cayman Islands'},
#   'countryiso3code': 'CYM',
#   'date': '2015',
#   'value': 0.00980000011622906,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CF', 'value': 'Central African Republic'},
#   'countryiso3code': 'CAF',
#   'date': '2015',
#   'value': 84.2345962524414,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TD', 'value': 'Chad'},
#   'countryiso3code': 'TCD',
#   'date': '2015',
#   'value': 85.2529983520508,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'JG', 'value': 'Channel Islands'},
#   'countryiso3code': 'CHI',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CL', 'value': 'Chile'},
#   'countryiso3code': 'CHL',
#   'date': '2015',
#   'value': 25.0650997161865,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CN', 'value': 'China'},
#   'countryiso3code': 'CHN',
#   'date': '2015',
#   'value': 12.2453002929688,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CO', 'value': 'Colombia'},
#   'countryiso3code': 'COL',
#   'date': '2015',
#   'value': 31.5995006561279,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KM', 'value': 'Comoros'},
#   'countryiso3code': 'COM',
#   'date': '2015',
#   'value': 64.1656036376953,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CD', 'value': 'Congo, Dem. Rep.'},
#   'countryiso3code': 'COD',
#   'date': '2015',
#   'value': 95.8182983398438,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CG', 'value': 'Congo, Rep.'},
#   'countryiso3code': 'COG',
#   'date': '2015',
#   'value': 64.1508026123047,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CR', 'value': 'Costa Rica'},
#   'countryiso3code': 'CRI',
#   'date': '2015',
#   'value': 38.326301574707,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CI', 'value': "Cote d'Ivoire"},
#   'countryiso3code': 'CIV',
#   'date': '2015',
#   'value': 64.8336029052734,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'HR', 'value': 'Croatia'},
#   'countryiso3code': 'HRV',
#   'date': '2015',
#   'value': 33.1091003417969,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CU', 'value': 'Cuba'},
#   'countryiso3code': 'CUB',
#   'date': '2015',
#   'value': 20.0916996002197,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CW', 'value': 'Curacao'},
#   'countryiso3code': 'CUW',
#   'date': '2015',
#   'value': 1.60150003433228,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CY', 'value': 'Cyprus'},
#   'countryiso3code': 'CYP',
#   'date': '2015',
#   'value': 10.5434999465942,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CZ', 'value': 'Czech Republic'},
#   'countryiso3code': 'CZE',
#   'date': '2015',
#   'value': 14.8454999923706,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DK', 'value': 'Denmark'},
#   'countryiso3code': 'DNK',
#   'date': '2015',
#   'value': 32.9777984619141,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DJ', 'value': 'Djibouti'},
#   'countryiso3code': 'DJI',
#   'date': '2015',
#   'value': 28.1802005767822,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DM', 'value': 'Dominica'},
#   'countryiso3code': 'DMA',
#   'date': '2015',
#   'value': 8.62759971618652,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DO', 'value': 'Dominican Republic'},
#   'countryiso3code': 'DOM',
#   'date': '2015',
#   'value': 15.0139999389648,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'EC', 'value': 'Ecuador'},
#   'countryiso3code': 'ECU',
#   'date': '2015',
#   'value': 13.0735998153687,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'EG', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': 'EGY',
#   'date': '2015',
#   'value': 5.11600017547607,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SV', 'value': 'El Salvador'},
#   'countryiso3code': 'SLV',
#   'date': '2015',
#   'value': 21.0300998687744,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GQ', 'value': 'Equatorial Guinea'},
#   'countryiso3code': 'GNQ',
#   'date': '2015',
#   'value': 4.53450012207031,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ER', 'value': 'Eritrea'},
#   'countryiso3code': 'ERI',
#   'date': '2015',
#   'value': 77.0761032104492,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'EE', 'value': 'Estonia'},
#   'countryiso3code': 'EST',
#   'date': '2015',
#   'value': 27.5559997558594,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SZ', 'value': 'Eswatini'},
#   'countryiso3code': 'SWZ',
#   'date': '2015',
#   'value': 66.5886993408203,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ET', 'value': 'Ethiopia'},
#   'countryiso3code': 'ETH',
#   'date': '2015',
#   'value': 91.5577011108398,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'FO', 'value': 'Faroe Islands'},
#   'countryiso3code': 'FRO',
#   'date': '2015',
#   'value': 7.47410011291504,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'FJ', 'value': 'Fiji'},
#   'countryiso3code': 'FJI',
#   'date': '2015',
#   'value': 32.6744995117188,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'FI', 'value': 'Finland'},
#   'countryiso3code': 'FIN',
#   'date': '2015',
#   'value': 43.2295989990234,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'FR', 'value': 'France'},
#   'countryiso3code': 'FRA',
#   'date': '2015',
#   'value': 13.4837999343872,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'PF', 'value': 'French Polynesia'},
#   'countryiso3code': 'PYF',
#   'date': '2015',
#   'value': 8.02060031890869,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GA', 'value': 'Gabon'},
#   'countryiso3code': 'GAB',
#   'date': '2015',
#   'value': 81.9297027587891,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GM', 'value': 'Gambia, The'},
#   'countryiso3code': 'GMB',
#   'date': '2015',
#   'value': 52.9114990234375,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GE', 'value': 'Georgia'},
#   'countryiso3code': 'GEO',
#   'date': '2015',
#   'value': 28.1485004425049,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'DE', 'value': 'Germany'},
#   'countryiso3code': 'DEU',
#   'date': '2015',
#   'value': 14.5502996444702,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GH', 'value': 'Ghana'},
#   'countryiso3code': 'GHA',
#   'date': '2015',
#   'value': 44.0498008728027,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GI', 'value': 'Gibraltar'},
#   'countryiso3code': 'GIB',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GR', 'value': 'Greece'},
#   'countryiso3code': 'GRC',
#   'date': '2015',
#   'value': 17.4748992919922,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GL', 'value': 'Greenland'},
#   'countryiso3code': 'GRL',
#   'date': '2015',
#   'value': 13.0651998519897,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GD', 'value': 'Grenada'},
#   'countryiso3code': 'GRD',
#   'date': '2015',
#   'value': 12.2786998748779,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GU', 'value': 'Guam'},
#   'countryiso3code': 'GUM',
#   'date': '2015',
#   'value': 1.26320004463196,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GT', 'value': 'Guatemala'},
#   'countryiso3code': 'GTM',
#   'date': '2015',
#   'value': 63.3911018371582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GN', 'value': 'Guinea'},
#   'countryiso3code': 'GIN',
#   'date': '2015',
#   'value': 76.2297973632813,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GW', 'value': 'Guinea-Bissau'},
#   'countryiso3code': 'GNB',
#   'date': '2015',
#   'value': 87.1517028808594,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GY', 'value': 'Guyana'},
#   'countryiso3code': 'GUY',
#   'date': '2015',
#   'value': 24.9480991363525,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'HT', 'value': 'Haiti'},
#   'countryiso3code': 'HTI',
#   'date': '2015',
#   'value': 76.11669921875,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'HN', 'value': 'Honduras'},
#   'countryiso3code': 'HND',
#   'date': '2015',
#   'value': 52.67919921875,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'HK', 'value': 'Hong Kong SAR, China'},
#   'countryiso3code': 'HKG',
#   'date': '2015',
#   'value': 0.206799998879433,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'HU', 'value': 'Hungary'},
#   'countryiso3code': 'HUN',
#   'date': '2015',
#   'value': 15.6000995635986,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IS', 'value': 'Iceland'},
#   'countryiso3code': 'ISL',
#   'date': '2015',
#   'value': 77.1162033081055,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IN', 'value': 'India'},
#   'countryiso3code': 'IND',
#   'date': '2015',
#   'value': 34.3959007263184,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ID', 'value': 'Indonesia'},
#   'countryiso3code': 'IDN',
#   'date': '2015',
#   'value': 26.9519004821777,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IR', 'value': 'Iran, Islamic Rep.'},
#   'countryiso3code': 'IRN',
#   'date': '2015',
#   'value': 0.906899988651276,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IQ', 'value': 'Iraq'},
#   'countryiso3code': 'IRQ',
#   'date': '2015',
#   'value': 0.803900003433228,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IE', 'value': 'Ireland'},
#   'countryiso3code': 'IRL',
#   'date': '2015',
#   'value': 9.09179973602295,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IM', 'value': 'Isle of Man'},
#   'countryiso3code': 'IMN',
#   'date': '2015',
#   'value': 2.16689991950989,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IL', 'value': 'Israel'},
#   'countryiso3code': 'ISR',
#   'date': '2015',
#   'value': 3.73850011825562,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'IT', 'value': 'Italy'},
#   'countryiso3code': 'ITA',
#   'date': '2015',
#   'value': 16.570499420166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'JM', 'value': 'Jamaica'},
#   'countryiso3code': 'JAM',
#   'date': '2015',
#   'value': 11.8043003082275,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'JP', 'value': 'Japan'},
#   'countryiso3code': 'JPN',
#   'date': '2015',
#   'value': 6.32340002059937,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'JO', 'value': 'Jordan'},
#   'countryiso3code': 'JOR',
#   'date': '2015',
#   'value': 3.23420000076294,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KZ', 'value': 'Kazakhstan'},
#   'countryiso3code': 'KAZ',
#   'date': '2015',
#   'value': 1.70659995079041,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KE', 'value': 'Kenya'},
#   'countryiso3code': 'KEN',
#   'date': '2015',
#   'value': 72.032096862793,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KI', 'value': 'Kiribati'},
#   'countryiso3code': 'KIR',
#   'date': '2015',
#   'value': 45.8204002380371,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KP', 'value': "Korea, Dem. People's Rep."},
#   'countryiso3code': 'PRK',
#   'date': '2015',
#   'value': 23.1072006225586,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2015',
#   'value': 2.74399995803833,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'XK', 'value': 'Kosovo'},
#   'countryiso3code': 'XKX',
#   'date': '2015',
#   'value': 20.4549007415771,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KW', 'value': 'Kuwait'},
#   'countryiso3code': 'KWT',
#   'date': '2015',
#   'value': 0.00370000000111759,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KG', 'value': 'Kyrgyz Republic'},
#   'countryiso3code': 'KGZ',
#   'date': '2015',
#   'value': 23.300199508667,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'LA', 'value': 'Lao PDR'},
#   'countryiso3code': 'LAO',
#   'date': '2015',
#   'value': 53.9000015258789,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'LV', 'value': 'Latvia'},
# ...
#   'value': 37.478199005127,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SM', 'value': 'San Marino'},
#   'countryiso3code': 'SMR',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ST', 'value': 'Sao Tome and Principe'},
#   'countryiso3code': 'STP',
#   'date': '2015',
#   'value': 40.2328987121582,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SA', 'value': 'Saudi Arabia'},
#   'countryiso3code': 'SAU',
#   'date': '2015',
#   'value': 0.0137999998405576,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SN', 'value': 'Senegal'},
#   'countryiso3code': 'SEN',
#   'date': '2015',
#   'value': 39.9331016540527,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'RS', 'value': 'Serbia'},
#   'countryiso3code': 'SRB',
#   'date': '2015',
#   'value': 21.3332004547119,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SC', 'value': 'Seychelles'},
#   'countryiso3code': 'SYC',
#   'date': '2015',
#   'value': 1.32169997692108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SL', 'value': 'Sierra Leone'},
#   'countryiso3code': 'SLE',
#   'date': '2015',
#   'value': 78.4597015380859,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SG', 'value': 'Singapore'},
#   'countryiso3code': 'SGP',
#   'date': '2015',
#   'value': 0.645099997520447,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SX', 'value': 'Sint Maarten (Dutch part)'},
#   'countryiso3code': 'SXM',
#   'date': '2015',
#   'value': 0.0474999994039536,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SK', 'value': 'Slovak Republic'},
#   'countryiso3code': 'SVK',
#   'date': '2015',
#   'value': 13.4084997177124,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SI', 'value': 'Slovenia'},
#   'countryiso3code': 'SVN',
#   'date': '2015',
#   'value': 20.8129005432129,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SB', 'value': 'Solomon Islands'},
#   'countryiso3code': 'SLB',
#   'date': '2015',
#   'value': 48.6451988220215,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SO', 'value': 'Somalia'},
#   'countryiso3code': 'SOM',
#   'date': '2015',
#   'value': 94.496696472168,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZA', 'value': 'South Africa'},
#   'countryiso3code': 'ZAF',
#   'date': '2015',
#   'value': 10.2917003631592,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SS', 'value': 'South Sudan'},
#   'countryiso3code': 'SSD',
#   'date': '2015',
#   'value': 26.703800201416,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ES', 'value': 'Spain'},
#   'countryiso3code': 'ESP',
#   'date': '2015',
#   'value': 16.2985000610352,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'LK', 'value': 'Sri Lanka'},
#   'countryiso3code': 'LKA',
#   'date': '2015',
#   'value': 52.8858985900879,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'KN', 'value': 'St. Kitts and Nevis'},
#   'countryiso3code': 'KNA',
#   'date': '2015',
#   'value': 1.7014000415802,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'LC', 'value': 'St. Lucia'},
#   'countryiso3code': 'LCA',
#   'date': '2015',
#   'value': 11.5195999145508,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'MF', 'value': 'St. Martin (French part)'},
#   'countryiso3code': 'MAF',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VC', 'value': 'St. Vincent and the Grenadines'},
#   'countryiso3code': 'VCT',
#   'date': '2015',
#   'value': 4.2975001335144,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SD', 'value': 'Sudan'},
#   'countryiso3code': 'SDN',
#   'date': '2015',
#   'value': 62.9984016418457,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SR', 'value': 'Suriname'},
#   'countryiso3code': 'SUR',
#   'date': '2015',
#   'value': 11.5937995910645,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SE', 'value': 'Sweden'},
#   'countryiso3code': 'SWE',
#   'date': '2015',
#   'value': 52.8914985656738,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'CH', 'value': 'Switzerland'},
#   'countryiso3code': 'CHE',
#   'date': '2015',
#   'value': 23.9573993682861,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'SY', 'value': 'Syrian Arab Republic'},
#   'countryiso3code': 'SYR',
#   'date': '2015',
#   'value': 0.606500029563904,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TJ', 'value': 'Tajikistan'},
#   'countryiso3code': 'TJK',
#   'date': '2015',
#   'value': 48.1095008850098,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TZ', 'value': 'Tanzania'},
#   'countryiso3code': 'TZA',
#   'date': '2015',
#   'value': 83.4881973266602,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TH', 'value': 'Thailand'},
#   'countryiso3code': 'THA',
#   'date': '2015',
#   'value': 22.6527996063232,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TL', 'value': 'Timor-Leste'},
#   'countryiso3code': 'TLS',
#   'date': '2015',
#   'value': 18.3500995635986,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TG', 'value': 'Togo'},
#   'countryiso3code': 'TGO',
#   'date': '2015',
#   'value': 81.0438995361328,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TO', 'value': 'Tonga'},
#   'countryiso3code': 'TON',
#   'date': '2015',
#   'value': 1.87969994544983,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TT', 'value': 'Trinidad and Tobago'},
#   'countryiso3code': 'TTO',
#   'date': '2015',
#   'value': 0.360300004482269,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TN', 'value': 'Tunisia'},
#   'countryiso3code': 'TUN',
#   'date': '2015',
#   'value': 12.4969997406006,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TR', 'value': 'Turkey'},
#   'countryiso3code': 'TUR',
#   'date': '2015',
#   'value': 13.3374004364014,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TM', 'value': 'Turkmenistan'},
#   'countryiso3code': 'TKM',
#   'date': '2015',
#   'value': 0.0553999990224838,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TC', 'value': 'Turks and Caicos Islands'},
#   'countryiso3code': 'TCA',
#   'date': '2015',
#   'value': 0.572200000286102,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'TV', 'value': 'Tuvalu'},
#   'countryiso3code': 'TUV',
#   'date': '2015',
#   'value': 5.32989978790283,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'UG', 'value': 'Uganda'},
#   'countryiso3code': 'UGA',
#   'date': '2015',
#   'value': 91.0727996826172,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'UA', 'value': 'Ukraine'},
#   'countryiso3code': 'UKR',
#   'date': '2015',
#   'value': 4.14249992370605,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'AE', 'value': 'United Arab Emirates'},
#   'countryiso3code': 'ARE',
#   'date': '2015',
#   'value': 0.126399993896484,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'GB', 'value': 'United Kingdom'},
#   'countryiso3code': 'GBR',
#   'date': '2015',
#   'value': 8.58769989013672,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 9.03390026092529,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'UY', 'value': 'Uruguay'},
#   'countryiso3code': 'URY',
#   'date': '2015',
#   'value': 59.3997001647949,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'UZ', 'value': 'Uzbekistan'},
#   'countryiso3code': 'UZB',
#   'date': '2015',
#   'value': 1.67369997501373,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VU', 'value': 'Vanuatu'},
#   'countryiso3code': 'VUT',
#   'date': '2015',
#   'value': 35.5386009216309,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VE', 'value': 'Venezuela, RB'},
#   'countryiso3code': 'VEN',
#   'date': '2015',
#   'value': 15.329400062561,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VN', 'value': 'Vietnam'},
#   'countryiso3code': 'VNM',
#   'date': '2015',
#   'value': 30.7199001312256,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'VI', 'value': 'Virgin Islands (U.S.)'},
#   'countryiso3code': 'VIR',
#   'date': '2015',
#   'value': 4.12659978866577,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'PS', 'value': 'West Bank and Gaza'},
#   'countryiso3code': 'PSE',
#   'date': '2015',
#   'value': 10.9940996170044,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'YE', 'value': 'Yemen, Rep.'},
#   'countryiso3code': 'YEM',
#   'date': '2015',
#   'value': 2.41950011253357,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZM', 'value': 'Zambia'},
#   'countryiso3code': 'ZMB',
#   'date': '2015',
#   'value': 85.4869995117188,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': 'EG.FEC.RNEW.ZS',
#    'value': 'Renewable energy consumption (% of total final energy consumption)'},
#   'country': {'id': 'ZW', 'value': 'Zimbabwe'},
#   'countryiso3code': 'ZWE',
#   'date': '2015',
#   'value': 81.4272003173828,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2}]

# %%
daf=wb.get_dataframe({"EG.FEC.RNEW.ZS":"Value"}, data_date=data_date)
daf
# Out:
#                                     Value
# country
# Africa Eastern and Southern     61.097264
# Africa Western and Central      76.967527
# Arab World                       4.080760
# Caribbean small states           6.907744
# Central Europe and the Baltics  17.120139
# ...                                   ...
# Virgin Islands (U.S.)            4.126600
# West Bank and Gaza              10.994100
# Yemen, Rep.                      2.419500
# Zambia                          85.487000
# Zimbabwe                        81.427200
#
# [266 rows x 1 columns]

# %% [markdown]
# ### - Undestanding the data
#
# * **_[TO DO]_**: Display different data points

# %%
### TODO


fus=daf.Value['World':]
#fus=daf.Value[:'World']
newfus = fus.sort_values(ascending=True)

newfus
plt.rcParams['figure.figsize'] = [100,25]
newfus.plot.bar()

# %% [markdown]
# ### - Exporting the data
#
# * **_[TO DO]_**: Save the retrieved renewable energy consumption data of all countries in 2015 in one .xlsx file
# * **_[TO DO]_**: Save the renewable energy consumption data from 2006 to 2016 for each European country in individual .csv files (one per country)

# %%
### TODO
daf.to_excel("Renewable energy consumption_2015.xlsx", index=True)
